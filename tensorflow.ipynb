# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import StandardScaler

# %%
x=np.arange(0,20,1).reshape(-1,1)
y=np.arange(0,40,2).reshape(-1,1)
noise = np.random.normal(0,2.5,len(x))
y = [elemA + elemB for elemA, elemB in zip(y,noise)]
plt.scatter(x,y)

# %%
scaler_x=StandardScaler()
x=scaler_x.fit_transform(x)

scaler_y=StandardScaler()
y=scaler_y.fit_transform(y)

# %%
#m= a*x+b
a=tf.Variable(0.23)#termo dependente
b=tf.Variable(0.35)#termo independente
error=tf.losses.mean_squared_error(y,(a*x+b))
otimizador=tf.train.
# Out:
# <tf.Tensor: shape=(20,), dtype=float32, numpy=
# array([3.1797318e+00, 8.7458229e-01, 1.5771849e+00, 2.1453056e+00,
#        6.2474030e-01, 2.1242306e-01, 1.2045407e+00, 1.0471979e+00,
#        3.8754967e-01, 3.5631415e-01, 8.8114806e-02, 4.1401360e-02,
#        1.0940881e-03, 1.6510101e-02, 1.8350394e-02, 2.4089548e-01,
#        4.1122520e-01, 5.6465185e-01, 1.4041424e+00, 2.5240597e-01],
#       dtype=float32)>
